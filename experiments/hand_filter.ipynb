# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, '..')

from preprocess.inspect_100doh import vis_dataset, get_dataloader
from jutils import image_utils

# %% [markdown]
# ## before filter

# %%
dataloader = get_dataloader('study_v_im0FA2X6fp0_frame000043_0')
file_list = vis_dataset(dataloader, 'before')

for gif_file in file_list:
    image_utils.display_gif(gif_file)
# Out:
# save to  /glusterfs/yufeiy2/vhoi/syn_data/vis/before_gt.gif
# save to  /glusterfs/yufeiy2/vhoi/syn_data/vis/before_cHand.gif
# save to  /glusterfs/yufeiy2/vhoi/syn_data/vis/before_hHand.gif
# save to  /glusterfs/yufeiy2/vhoi/syn_data/vis/before_hHand_1.gif

# %% [markdown]
# ## Kalman (other?) filter??

# %% [markdown]
# ## Temporal loss

# %%
image_utils.display_gif('/glusterfs/yufeiy2/vhoi/syn_data/vis/opt_cHand.gif')
image_utils.display_gif('/glusterfs/yufeiy2/vhoi/syn_data/vis/opt_hHand.gif')
image_utils.display_gif('/glusterfs/yufeiy2/vhoi/syn_data/vis/opt_hHand_1.gif')
